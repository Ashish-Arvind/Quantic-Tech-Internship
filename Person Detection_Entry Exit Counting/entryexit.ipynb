# %% [markdown]
# ### Deep SORT

# %%
import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

model = YOLO("yolov8l.pt")
tracker = DeepSort(max_age=30)

cap = cv2.VideoCapture('entry_exit_input.mp4')

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('entry_exit_output.mp4', fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]

    detections = []
    for box in results.boxes:
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])
        if cls_id == 0 and conf > 0.6:
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
            detections.append(([x1, y1, x2 - x1, y2 - y1], conf, 'person'))

    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 1)
        cv2.putText(frame, f'ID: {track_id}', (x1, y1 - 10),
                    cv2.FONT_HERSHEY_DUPLEX, 0.5, (0, 0, 255), 1)

    cv2.imshow("Person Tracking", frame)

    out.write(frame)
    
    if cv2.waitKey(1) == ord("q"):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# D:\Studies\venvs\cvprojenv\Lib\site-packages\deep_sort_realtime\embedder\embedder_pytorch.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 0: 480x640 1 person, 2 chairs, 161.2ms
# Speed: 3.0ms preprocess, 161.2ms inference, 107.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 40.4ms
# Speed: 2.3ms preprocess, 40.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 40.1ms
# Speed: 2.4ms preprocess, 40.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 39.8ms
# Speed: 1.6ms preprocess, 39.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 41.2ms
# Speed: 1.7ms preprocess, 41.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 41.2ms
# Speed: 1.5ms preprocess, 41.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 dining table, 38.4ms
# Speed: 1.8ms preprocess, 38.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 dining table, 39.2ms
# Speed: 1.9ms preprocess, 39.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 2 dining tables, 38.7ms
# Speed: 1.4ms preprocess, 38.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 2 dining tables, 39.5ms
# Speed: 2.1ms preprocess, 39.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 dining table, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 dining table, 37.2ms
# Speed: 1.9ms preprocess, 37.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 dining table, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 dining table, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 2 dining tables, 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 2 dining tables, 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 dining table, 36.1ms
# Speed: 2.8ms preprocess, 36.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 dining table, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 dining table, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 dining table, 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 dining table, 38.8ms
# Speed: 1.9ms preprocess, 38.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ### Inbuilt YOLO.track() (ByteTrack implementation)

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolov8l.pt")

IGNORE_REGION = (400, 0, 640, 150)  # (x1, y1, x2, y2)

cap = cv2.VideoCapture("entry_exit_input.mp4")

ret, frame = cap.read()
H, W = frame.shape[:2]
cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("entry_exit_output.mp4", fourcc, cap.get(cv2.CAP_PROP_FPS), (W, H))

# detection region (bottom-right corner)
region_x1 = int(H * 0.5)
region_y1 = int(H * 0.65)
region_x2 = W
region_y2 = H

# Tracking info
track_memory = {}
in_count = 0
out_count = 0

# Check if point is inside the region
def is_inside_region(x, y):
    return region_x1 <= x <= region_x2 and region_y1 <= y <= region_y2

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Mask ignore region before detection
    x1, y1, x2, y2 = IGNORE_REGION
    frame[y1:y2, x1:x2] = 0

    results = model.track(source=frame, persist=True, stream=False, classes=[0])
    result = results[0]

    annotated = result.plot(line_width=1, font_size=0.4)

    overlay = annotated.copy()
    cv2.rectangle(annotated, (region_x1, region_y1), (region_x2, region_y2), (0, 255, 0), -1) #-1 -> fill
    alpha = 0.8  # 30% opacity
    cv2.addWeighted(overlay, alpha, annotated, 1 - alpha, 0, annotated)

    if result.boxes.id is not None:
        ids = result.boxes.id.int().tolist()
        boxes = result.boxes.xyxy.cpu().numpy()

        current_ids = set(ids)

        for id_, box in zip(ids, boxes):
            x1, y1, x2, y2 = box
            cx, cy = int((x1 + x2) // 2), int((y1 + y2) // 2)
            cv2.circle(annotated, (cx, cy), radius=3, color=(0, 0, 255), thickness=-1)

            curr_inside = is_inside_region(cx, cy)
            prev_data = track_memory.get(id_, {"inside": curr_inside, "counted": False})

            prev_inside = prev_data["inside"]
            counted = prev_data["counted"]

            if not counted:
                if not prev_inside and curr_inside:
                    in_count += 1
                    counted = True
                elif prev_inside and not curr_inside:
                    out_count += 1
                    counted = True

            track_memory[id_] = {"inside": curr_inside, "counted": counted}

        for old_id in list(track_memory.keys()):
            if old_id not in current_ids:
                del track_memory[old_id]

    cv2.putText(annotated, f"IN: {in_count}", (10, 25), cv2.FONT_HERSHEY_DUPLEX, 0.6, (0, 255, 0), 1)
    cv2.putText(annotated, f"OUT: {out_count}", (10, 50), cv2.FONT_HERSHEY_DUPLEX, 0.6, (0, 0, 255), 1)
    cv2.putText(annotated, f"INSIDE: {abs(in_count-out_count)}", (10, 75), cv2.FONT_HERSHEY_DUPLEX, 0.6, (0, 255, 255), 1)

    cv2.imshow("Entry Exit Tracking", annotated)
    out.write(annotated)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 43.5ms
# Speed: 2.0ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 2.0ms preprocess, 41.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.6ms
# Speed: 1.2ms preprocess, 40.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.5ms preprocess, 42.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 2.4ms preprocess, 42.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.6ms preprocess, 41.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 2.1ms preprocess, 42.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.7ms
# Speed: 1.8ms preprocess, 40.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.4ms
# Speed: 1.2ms preprocess, 40.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 2.4ms preprocess, 41.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 1.7ms preprocess, 42.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.5ms preprocess, 42.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.8ms preprocess, 42.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 2.0ms preprocess, 42.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 1.4ms preprocess, 38.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 2.2ms preprocess, 42.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Speed: 1.3ms preprocess, 43.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.9ms preprocess, 42.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Speed: 1.2ms preprocess, 41.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.4ms
# Speed: 1.7ms preprocess, 39.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.9ms preprocess, 42.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.0ms
# Speed: 1.1ms preprocess, 41.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.6ms preprocess, 42.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.9ms preprocess, 42.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Speed: 1.4ms preprocess, 41.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.3ms preprocess, 41.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 2.1ms preprocess, 41.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Speed: 1.5ms preprocess, 43.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.6ms preprocess, 42.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Speed: 1.9ms preprocess, 41.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 1.7ms preprocess, 42.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.8ms preprocess, 41.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Speed: 2.1ms preprocess, 43.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Speed: 2.3ms preprocess, 42.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.5ms preprocess, 41.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.3ms preprocess, 41.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.1ms
# Speed: 1.6ms preprocess, 38.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.3ms preprocess, 43.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Speed: 1.5ms preprocess, 43.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.9ms
# Speed: 2.4ms preprocess, 39.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.3ms preprocess, 43.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.8ms preprocess, 42.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.8ms preprocess, 42.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.6ms preprocess, 43.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 1.2ms preprocess, 42.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Speed: 1.6ms preprocess, 43.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.1ms
# Speed: 1.4ms preprocess, 38.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.8ms
# Speed: 2.1ms preprocess, 40.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 3.8ms preprocess, 42.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 2.1ms preprocess, 42.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 2.0ms preprocess, 42.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 1.7ms preprocess, 42.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 2.2ms preprocess, 42.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.9ms preprocess, 43.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 2.1ms preprocess, 42.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.3ms
# Speed: 1.6ms preprocess, 42.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.9ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.3ms preprocess, 43.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 1.3ms preprocess, 43.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 2.1ms preprocess, 42.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 2.4ms preprocess, 43.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 1.6ms preprocess, 44.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 1.8ms preprocess, 42.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.4ms
# Speed: 1.9ms preprocess, 38.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.9ms
# Speed: 1.6ms preprocess, 48.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.8ms
# Speed: 1.5ms preprocess, 48.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.4ms
# Speed: 2.1ms preprocess, 41.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.7ms
# Speed: 1.4ms preprocess, 43.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 1.6ms preprocess, 42.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.6ms preprocess, 42.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.3ms
# Speed: 1.5ms preprocess, 41.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 1.7ms preprocess, 43.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.6ms preprocess, 42.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 6.4ms preprocess, 41.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.4ms
# Speed: 1.6ms preprocess, 44.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 2.1ms preprocess, 42.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.4ms
# Speed: 1.3ms preprocess, 42.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.9ms preprocess, 43.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.9ms
# Speed: 1.4ms preprocess, 41.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.5ms
# Speed: 2.7ms preprocess, 41.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 2.5ms preprocess, 42.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.3ms preprocess, 43.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.8ms
# Speed: 2.7ms preprocess, 40.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 2.0ms preprocess, 42.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 1.3ms preprocess, 43.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.9ms preprocess, 43.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.9ms preprocess, 42.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 1.8ms preprocess, 43.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.3ms
# Speed: 1.6ms preprocess, 44.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.3ms
# Speed: 1.5ms preprocess, 42.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 1.7ms preprocess, 43.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.7ms
# Speed: 1.8ms preprocess, 40.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.7ms
# Speed: 1.4ms preprocess, 39.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 2.1ms preprocess, 42.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.9ms
# Speed: 1.9ms preprocess, 41.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.4ms
# Speed: 2.0ms preprocess, 41.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.5ms
# Speed: 2.4ms preprocess, 41.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.0ms
# Speed: 1.5ms preprocess, 39.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 2.0ms preprocess, 42.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.4ms
# Speed: 1.8ms preprocess, 42.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.8ms
# Speed: 1.4ms preprocess, 44.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.1ms
# Speed: 1.6ms preprocess, 43.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.4ms
# Speed: 1.6ms preprocess, 42.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.0ms
# Speed: 1.6ms preprocess, 42.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.7ms
# Speed: 1.6ms preprocess, 43.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
#
# 0: 480x640 1 person, 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 2.2ms preprocess, 42.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 2.1ms preprocess, 41.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Speed: 1.9ms preprocess, 43.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Speed: 1.7ms preprocess, 43.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.8ms preprocess, 41.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 2.1ms preprocess, 43.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.5ms
# Speed: 1.8ms preprocess, 44.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.3ms
# Speed: 2.0ms preprocess, 40.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.3ms
# Speed: 2.1ms preprocess, 44.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 2.3ms preprocess, 41.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 2.1ms preprocess, 42.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.3ms
# Speed: 2.8ms preprocess, 44.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.1ms
# Speed: 1.9ms preprocess, 40.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.2ms
# Speed: 1.8ms preprocess, 40.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 2.9ms preprocess, 43.4ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.0ms
# Speed: 2.4ms preprocess, 40.0ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 42.0ms
# Speed: 2.7ms preprocess, 42.0ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.1ms
# Speed: 2.6ms preprocess, 40.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.4ms
# Speed: 2.3ms preprocess, 44.4ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.0ms
# Speed: 2.1ms preprocess, 41.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.0ms
# Speed: 1.8ms preprocess, 44.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 2.2ms preprocess, 43.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 2.8ms preprocess, 42.3ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 40.2ms
# Speed: 2.1ms preprocess, 40.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.3ms
# Speed: 2.1ms preprocess, 43.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.4ms
# Speed: 2.0ms preprocess, 41.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.8ms
# Speed: 2.3ms preprocess, 43.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 2.3ms preprocess, 42.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 1.8ms preprocess, 43.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.4ms
# Speed: 2.1ms preprocess, 41.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.9ms
# Speed: 1.7ms preprocess, 43.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.3ms
# Speed: 2.2ms preprocess, 44.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.8ms
# Speed: 2.0ms preprocess, 40.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 2.2ms preprocess, 43.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 2.0ms preprocess, 43.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.1ms
# Speed: 1.9ms preprocess, 41.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.8ms
# Speed: 1.7ms preprocess, 39.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.1ms
# Speed: 2.2ms preprocess, 44.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.8ms
# Speed: 2.1ms preprocess, 43.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 2.7ms preprocess, 43.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.7ms
# Speed: 2.2ms preprocess, 43.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.8ms
# Speed: 2.1ms preprocess, 43.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 2.3ms preprocess, 43.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.7ms
# Speed: 1.9ms preprocess, 44.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 1.7ms preprocess, 43.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.0ms
# Speed: 2.2ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 2.5ms preprocess, 43.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.7ms
# Speed: 2.0ms preprocess, 43.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.4ms
# Speed: 2.1ms preprocess, 44.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.3ms
# Speed: 2.5ms preprocess, 44.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.8ms
# Speed: 2.0ms preprocess, 40.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.8ms
# Speed: 2.5ms preprocess, 39.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.5ms
# Speed: 2.3ms preprocess, 44.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.8ms
# Speed: 2.5ms preprocess, 42.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.6ms
# Speed: 2.1ms preprocess, 41.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 2.6ms preprocess, 41.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.3ms
# Speed: 2.0ms preprocess, 44.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 1.9ms preprocess, 43.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 2.1ms preprocess, 43.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.7ms
# Speed: 2.3ms preprocess, 43.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.9ms
# Speed: 2.1ms preprocess, 42.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 1.8ms preprocess, 44.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.7ms
# Speed: 2.0ms preprocess, 43.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.9ms
# Speed: 2.5ms preprocess, 40.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.1ms
# Speed: 2.9ms preprocess, 44.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 2.2ms preprocess, 42.6ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.1ms
# Speed: 1.8ms preprocess, 42.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 2.0ms preprocess, 43.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 2.0ms preprocess, 44.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.2ms
# Speed: 1.9ms preprocess, 43.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.7ms
# Speed: 1.7ms preprocess, 44.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.1ms
# Speed: 2.3ms preprocess, 44.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 2.1ms preprocess, 43.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.9ms
# Speed: 4.0ms preprocess, 41.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.1ms
# Speed: 1.8ms preprocess, 41.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.1ms
# Speed: 1.9ms preprocess, 43.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.5ms
# Speed: 1.9ms preprocess, 44.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.3ms
# Speed: 2.0ms preprocess, 44.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.3ms
# Speed: 1.9ms preprocess, 41.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.8ms
# Speed: 2.3ms preprocess, 43.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.5ms
# Speed: 1.7ms preprocess, 44.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 1.8ms preprocess, 44.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 2.1ms preprocess, 43.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.2ms
# Speed: 1.9ms preprocess, 45.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.6ms
# Speed: 1.8ms preprocess, 39.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.9ms
# Speed: 2.0ms preprocess, 43.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 2.0ms preprocess, 43.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 2.1ms preprocess, 44.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.0ms
# Speed: 1.9ms preprocess, 41.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.0ms
# Speed: 2.1ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.0ms
# Speed: 1.9ms preprocess, 40.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 2.5ms preprocess, 44.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 2.1ms preprocess, 43.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 2.2ms preprocess, 40.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 1.8ms preprocess, 41.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.0ms
# Speed: 1.9ms preprocess, 44.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.7ms
# Speed: 2.4ms preprocess, 43.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.6ms
# Speed: 2.2ms preprocess, 44.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
